# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\dipal\Downloads\archive (3)\WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
print (df)
df.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df["TotalCharges"] = df ["TotalCharges"].replace(" ",0)

# %%
df["TotalCharges"] = df ["TotalCharges"].astype("float")

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["TotalCharges"].duplicated().sum()
# Out:
# np.int64(512)

# %%
def conv(value):
    if value == 1:
        return "yes"
    else:
        return "no"
df['SeniorCitizen']   = df["SeniorCitizen"].apply(conv)

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            no     Yes         No       1           No
# 1  5575-GNVDE    Male            no      No         No      34          Yes
# 2  3668-QPYBK    Male            no      No         No       2          Yes
# 3  7795-CFOCW    Male            no      No         No      45           No
# 4  9237-HQITU  Female            no      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# #### converted 0 and 1 values of senior citizen to yes/no to make it easier to understand

# %%
ax = sns.countplot(x = 'Churn',data = df)
ax.bar_label(ax.containers[0])
plt.title("Count of customers by Churn")
plt.show()

# %%
plt.figure(figsize = (3,4))
gb = df.groupby("Churn").agg({'Churn':"count"})
plt.pie(gb['Churn'],labels = gb.index, autopct = "%1.0f%%")
plt.title("Percentage of Churn Customber",fontsize = 10)
plt.show()

# %% [markdown]
# #### from the given pie chart we can conclude that 26.54 % of our Customber have churned out . not lets explore that revision behind it

# %%
plt.figure(figsize = (4,4))
ax = sns.countplot (x = "SeniorCitizen", data = df, hue = "Churn")
plt.title("Churn by SeniorCitizen")
ax.bar_label(ax.containers[0])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   object
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Create a cross-tab of counts
gender_churn = pd.crosstab(df['SeniorCitizen'], df['Churn'])

# Step 2: Convert counts to percentages row-wise
gender_churn_percent = gender_churn.div(gender_churn.sum(axis=1), axis=0) * 100

# Step 3: Plot stacked bar chart
ax = gender_churn_percent.plot(kind='bar', stacked=True, figsize=(6,4), colormap='Set2')

# Step 4: Add % labels to each section of bar
for container in ax.containers:
    labels = [f'{v.get_height():.1f}%' if v.get_height() > 0 else '' for v in container]
    ax.bar_label(container, labels=labels, label_type='center', fontsize=10, color='black')

# Final touches
plt.title("Churn by SeniorCitizen (Stacked Bar Chart)", fontsize=13)
plt.ylabel("Percentage")
plt.xlabel("SeniorCitizen")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### comparative a greater percentage of people in senior citizen category have churned

# %%
plt.figure(figsize = (9,4))
sns.histplot(x = "tenure", data = df, bins = 72, hue = "Churn")
plt.show()

# %% [markdown]
# #### people who have used our services for a long time have stayed and people who have used our services 1 to 20 have churned

# %%
plt.figure(figsize = (4,4))
ax = sns.countplot (x = "Contract", data = df, hue = "Churn")
plt.title("Churn of Customber  by Contract")
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# #### people who have month contract are likely to churn then who have 1 or 2 years or contract.

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset
# df = pd.read_csv("your_file.csv")  # Make sure df is already loaded

# List of categorical columns (you can modify as needed)
cat_columns = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
               'PhoneService', 'MultipleLines', 'InternetService',
               'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
               'TechSupport', 'StreamingTV', 'StreamingMovies',
               'Contract', 'PaperlessBilling', 'PaymentMethod']

# Plotting setup
n_cols = 3
n_rows = (len(cat_columns) + n_cols - 1) // n_cols

plt.figure(figsize=(n_cols*5, n_rows*4))

for i, col in enumerate(cat_columns, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.countplot(x=col, data=df, hue='Churn', palette='Set2')
    plt.title(f"{col} vs Churn")
    plt.xticks(rotation=30)
    plt.xlabel('')
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'SeniorCitizen' to categorical (Yes/No) if it's 0/1
df['SeniorCitizen'] = df['SeniorCitizen'].replace({0: 'No', 1: 'Yes'})

# List of categorical columns (excluding 'customerID', 'tenure', 'MonthlyCharges', 'TotalCharges')
cat_columns = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
               'PhoneService', 'MultipleLines', 'InternetService',
               'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
               'TechSupport', 'StreamingTV', 'StreamingMovies',
               'Contract', 'PaperlessBilling', 'PaymentMethod']

# Setup for subplots
n_cols = 3
n_rows = (len(cat_columns) + n_cols - 1) // n_cols
plt.figure(figsize=(n_cols * 5, n_rows * 4))

# Loop and plot
for i, col in enumerate(cat_columns, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.countplot(data=df, x=col, hue='Churn', palette='Set2')
    plt.title(f"{col} vs Churn")
    plt.xticks(rotation=30)
    plt.xlabel('')
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure SeniorCitizen is Yes/No
df['SeniorCitizen'] = df['SeniorCitizen'].replace({0: 'No', 1: 'Yes'})

# List of categorical columns
cat_columns = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
               'PhoneService', 'MultipleLines', 'InternetService',
               'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
               'TechSupport', 'StreamingTV', 'StreamingMovies',
               'Contract', 'PaperlessBilling', 'PaymentMethod']

# Define subplot grid size
n_cols = 3
n_rows = (len(cat_columns) + n_cols - 1) // n_cols

# Create figure and axes
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 4))
axes = axes.flatten()  # Flatten to easily index with a loop

# Plot each countplot in its subplot
for i, col in enumerate(cat_columns):
    sns.countplot(data=df, x=col, hue='Churn', palette='Set2', ax=axes[i])
    axes[i].set_title( f"{col} Count Plot")
    axes[i].tick_params(axis='x', rotation=30)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Count')

# Hide any unused axes (in case total columns < n_rows * n_cols)
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### The majority of customers across all categories did not churn However, churn tends to be higher among customers without partners, those with fiber optic internet, no online security or tech support, and those on month-to-month contracts. Services like online backup, device protection, and streaming TV also show a visible correlation with increased churn when not subscribed.

# %%
plt.figure(figsize = (4,4))
ax = sns.countplot (x = "PaymentMethod", data = df, hue = "Churn")
plt.title("Churn Customers by Payment Method")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ##### customer is likely to churn when he is using electronic chek as payment method
